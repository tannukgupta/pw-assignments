# %% [markdown]
# #Assignment 2-data structure

# %% [markdown]
# ###Data Types and Structures Questions

# %% [markdown]
# Q1. Data structures are specialized formats for organizing, processing, and storing data in a computer, such as arrays, lists, trees, stacks, queues, dictionaries, and sets.
#
# importance of data structures are-
# - helps in manage large amount of data.
# -enable modification of data efficiently.

# %% [markdown]
# Q2. Mutable data types: Can be changed after creation.
#   - Example: Lists in Python.
#     - my_list = [1, 2, 3]
#     my_list[0] = 100
#    changing the value in list to [100, 2, 3]
#
# Immutable data types: Cannot be changed after creation.
#   - Example: Strings and tuples in Python.
#    - my_str = "hello"
#   my_str[0] = "H"
#   it will show TypeError; cannot mutate strings

# %% [markdown]
# Q3. list
#
# 1.  mutable
# 2.  collection can be modified
# 3.  many methods can be used like, append,extend etc.
#
# tuple
# 1.   immutable
# 2.   it has fixed collection, integrity.
# 3.   few methods can be used like, count, index.

# %% [markdown]
# Q4. Dictionaries store data as key-value pairs using a built-in hash table mechanism. Each key must be unique and immutable, the value can be of any data type like float, string, integer or boolean.

# %% [markdown]
# Q5.
#
# *   stes automatically remove duplicates.
# *   helpful for mathematics operations.

# %% [markdown]
# Q6. String is An immutable sequence of characters eg, tannu, delhi, college.
#
# difference from list
# *   it is mutable
# *   it can have any data type

# %% [markdown]
# Q7. Tuples are immutable, meaning their contents can't be changed after creation, which protects data from accidental modification. They're often used for fixed collections of items.

# %% [markdown]
# Q8. Hash Table is a data structure that maps keys to values using a hash function to assign each key to a unique slot.
#
# - Python dictionaries use hash tables internally, enabling fast key-based look-up and insertion.

# %% [markdown]
# Q9. Yes, lists in Python are heterogeneous, which means their elements can be of mixed data types.
# python.
# mixed = [1, "two", 3.0, 4, 5]

# %% [markdown]
# Q10. String is immutabile because
# - it Provides security and thread safety.
# - it Allows internal optimizations.
#
# eg: Any operation that modifies a string creates a new object.
# python
# a = "hi"
# b = a.replace("h", "H")
#  a is still "hi"; b is "Hi"

# %% [markdown]
# Q11.
# - Fast look-up, insertion, and deletion by key .
# - Associative storage for named data.
# - No need to search through values to find a specific element.

# %% [markdown]
# Q12. Sets automatically remove duplicates. Adding a value already in a set has no effect.
#
# eg:
# my_set = {1, 2, 2, 3}
# Result: {1, 2, 3}

# %% [markdown]
# Q13. Tuples are often used for fixed collections, or fixed group of data.
# They're preferred when data shouldn't change.

# %% [markdown]
# Q14.
# - in lists it Checks if a value is present.
#   4 in [1, 2, 3, 4]  result True
#
# - in Dictionaries it  Checks if a key is present.
#   "name" in {"name": "Alice"}  result True

# %% [markdown]
# Q15. No, tuples are immutable. Their elements and length cannot be changed or altered after creation.

# %% [markdown]
# Q16. A nested dictionary is a dictionary inside another dictionary.

# %%
#Eg: Storing structured data like student records by ID.
students = {
  101: {"name": "Alice", "age": 20},
  102: {"name": "Bob", "age": 21}
}

# %% [markdown]
# Q17. Accessing an element by key in a dictionary has average-case time complexity, thanks to the hash table implementation.

# %% [markdown]
# Q18. list are prefered over dictionaries,
# - When you need an ordered collection.
# - When indexing by position is required.
# - When duplicate values are important.
# - For simple sequences of data

# %% [markdown]
# Q19.  dictionaries had no guaranteed order. Even though as of Python many dictionaries maintain insertion order, this behavior shouldn't be relied upon if you want your code to be backward-compatible. Retrieval by index is not supported; you must use keys.

# %% [markdown]
# Q20. list
#
#
# 1.   has numeric index
# 2.   odered sequences and duplicates are present
# 3.   O(1) for index, O(n) for search
#
# dictionary
#
# 1.   has unique key
# 2.   Unique identifiers to values
# 3.   O(1) for key, O(n) for value

# %% [markdown]
# ### practical questions with code

# %%
# 1
name = "Gupta"
print(name)
# Out:
# Gupta

# %%
# 2
print(len("Hello World"))
# Out:
# 11

# %%
# 3
print("Python Programming"[:3])
# Out:
# Pyt

# %%
# 4
print("hello".upper())
# Out:
# HELLO

# %%
# 5
print("I like apple".replace("apple", "orange"))
# Out:
# I like orange

# %%
# 6
numbers = [1, 2, 3, 4, 5]
print(numbers)
# Out:
# [1, 2, 3, 4, 5]

# %%
# 7
list = [1, 2, 3, 4]
list.append(10)
print(list)
# Out:
# [1, 2, 3, 4, 10]

# %%
# 8
list = [1, 2, 3, 4, 5]
list.remove(3)
print(list)
# Out:
# [1, 2, 4, 5]

# %%
# 9
chars = ['a', 'b', 'c', 'd']
print(chars[1])
# Out:
# b

# %%
# 10
lst = [10, 20, 30, 40, 50]
print(lst[::-1])
# Out:
# [50, 40, 30, 20, 10]

# %%
# 11
tup = (100, 200, 300)
print(tup)
# Out:
# (100, 200, 300)

# %%
# 12
colors = ('red', 'green', 'blue', 'yellow')
print(colors[-2])
# Out:
# blue

# %%
# 13
nums = (10, 20, 5, 15)
print(min(nums))
# Out:
# 5

# %%
# 14
animals = ('dog', 'cat', 'rabbit')
print(animals.index("cat"))
# Out:
# 1

# %%
# 15
fruits = ("apple", "banana", "mango")
print("kiwi" in fruits)
# Out:
# False

# %%
# 16
s = {'a', 'b', 'c'}
print(s)
# Out:
# {'b', 'c', 'a'}

# %%
# 17
s = {1, 2, 3, 4, 5}
s.clear()
print(s)
# Out:
# set()

# %%
# 18
s = {1, 2, 3, 4}
s.remove(4)
print(s)
# Out:
# {1, 2, 3}

# %%
# 19
a = {1, 2, 3}
b = {3, 4, 5}
print(a.union(b))
# Out:
# {1, 2, 3, 4, 5}

# %%
# 20
a = {1, 2, 3}
b = {2, 3, 4}
print(a.intersection(b))
# Out:
# {2, 3}

# %%
# 21
person = {"name": "John", "age": 25, "city": "New York"}
print(person)
# Out:
# {'name': 'John', 'age': 25, 'city': 'New York'}

# %%
# 22
person = {'name': 'John', 'age': 25}
person["country"] = "USA"
print(person)
# Out:
# {'name': 'John', 'age': 25, 'country': 'USA'}

# %%
# 23
person = {'name': 'Alice', 'age': 30}
print(person["name"])
# Out:
# Alice

# %%
# 24
person = {'name': 'Bob', 'age': 22, 'city': 'New York'}
del person["age"]
print(person)
# Out:
# {'name': 'Bob', 'city': 'New York'}

# %%
# 25
person = {'name': 'Alice', 'city': 'Paris'}
print("city" in person)
# Out:
# True

# %%
# 26
lst = [1, 2, 3]
tup = (4, 5, 6)
dct = {"a": 1, "b": 2}
print(lst, tup, dct)
# Out:
# [1, 2, 3] (4, 5, 6) {'a': 1, 'b': 2}

# %%
# 27
import random
nums = random.sample(range(1, 101), 5)
nums.sort()
print(nums)
# Out:
# [1, 7, 11, 26, 97]

# %%
# 28
words = ["apple", "banana", "cherry", "date", "fig"]
print(words[3])
# Out:
# date

# %%
# 29
dict1 = {"a": 1}
dict2 = {"b": 2}
combined = {**dict1, **dict2}
print(combined)
# Out:
# {'a': 1, 'b': 2}

# %%
# 30
words = ["apple", "banana", "apple"]
print(set(words))
# Out:
# {'apple', 'banana'}
